# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/y0uC4N/preprocessing/type1.csv')

sample_fraction = 0.5
df = df.sample(frac=sample_fraction, random_state=42)

df
# Out:
#           type        time  isCan0  priority  messageID  isService  \
# 170494  Normal  144.551090       1         5       1030          0
# 185051  Attack  152.749498       1         5       1030          0
# 138810  Normal  122.627257       1         5       1030          0
# 48125   Attack   63.020521       1         5       1030          0
# 118988  Normal  109.164858       1         5       1030          0
# ...        ...         ...     ...       ...        ...        ...
# 11546   Normal   30.327173       1         5       1030          0
# 176735  Attack  148.060307       1         5       1030          0
# 97781   Attack   97.347316       1         5       1030          0
# 142209  Normal  128.315927       1         5       1030          0
# 184708  Attack  152.555993       1         5       1030          0
#
#         serviceNODEID  byteSize  data[0]  data[1]  data[2]  data[3]  data[4]  \
# 170494              1         8      250      106       88       65      196
# 185051              1         7        0        0        0        0        0
# 138810              1         7      127      223        0       64        1
# 48125               1         8      166       53        0        0        0
# 118988              1         7      127      223        0       64        1
# ...               ...       ...      ...      ...      ...      ...      ...
# 11546               1         8      227      210      129       67       40
# 176735              1         8      166       53        0        0        0
# 97781               1         7        0        0        0        0        0
# 142209              1         7       63      223        0       64        1
# 184708              1         8      166       53        0        0        0
#
#         data[5]  data[6]  data[7]  7byteNullCnt  8byteNullCnt
# 170494      253        0      141             0             1
# 185051        0      124       -1             6             0
# 138810        0      112       -1             2             0
# 48125         0        0      139             0             5
# 118988        0      109       -1             2             0
# ...         ...      ...      ...           ...           ...
# 11546       244      240      153             0             0
# 176735        0        0      155             0             5
# 97781         0       97       -1             6             0
# 142209        0       97       -1             2             0
# 184708        0        0      159             0             5
#
# [103929 rows x 18 columns]

# %%
df.isnull().sum()
df
# Out:
#           type        time  isCan0  priority  messageID  isService  \
# 170494  Normal  144.551090       1         5       1030          0
# 185051  Attack  152.749498       1         5       1030          0
# 138810  Normal  122.627257       1         5       1030          0
# 48125   Attack   63.020521       1         5       1030          0
# 118988  Normal  109.164858       1         5       1030          0
# ...        ...         ...     ...       ...        ...        ...
# 11546   Normal   30.327173       1         5       1030          0
# 176735  Attack  148.060307       1         5       1030          0
# 97781   Attack   97.347316       1         5       1030          0
# 142209  Normal  128.315927       1         5       1030          0
# 184708  Attack  152.555993       1         5       1030          0
#
#         serviceNODEID  byteSize  data[0]  data[1]  data[2]  data[3]  data[4]  \
# 170494              1         8      250      106       88       65      196
# 185051              1         7        0        0        0        0        0
# 138810              1         7      127      223        0       64        1
# 48125               1         8      166       53        0        0        0
# 118988              1         7      127      223        0       64        1
# ...               ...       ...      ...      ...      ...      ...      ...
# 11546               1         8      227      210      129       67       40
# 176735              1         8      166       53        0        0        0
# 97781               1         7        0        0        0        0        0
# 142209              1         7       63      223        0       64        1
# 184708              1         8      166       53        0        0        0
#
#         data[5]  data[6]  data[7]  7byteNullCnt  8byteNullCnt
# 170494      253        0      141             0             1
# 185051        0      124       -1             6             0
# 138810        0      112       -1             2             0
# 48125         0        0      139             0             5
# 118988        0      109       -1             2             0
# ...         ...      ...      ...           ...           ...
# 11546       244      240      153             0             0
# 176735        0        0      155             0             5
# 97781         0       97       -1             6             0
# 142209        0       97       -1             2             0
# 184708        0        0      159             0             5
#
# [103929 rows x 18 columns]

# %%
x=df.drop('type',axis=1)
y=df['type']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
x_train=x_train.drop('isCan0',axis=1)
x_train=x_train.drop('isService',axis=1)
x_test=x_test.drop('isCan0',axis=1)
x_test=x_test.drop('isService',axis=1)

corr=x_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_72ee7_row0_col0, #T_72ee7_row1_col1, #T_72ee7_row2_col2, #T_72ee7_row3_col3, #T_72ee7_row4_col4, #T_72ee7_row5_col5, #T_72ee7_row6_col6, #T_72ee7_row7_col7, #T_72ee7_row8_col8, #T_72ee7_row9_col9, #T_72ee7_row10_col10, #T_72ee7_row11_col11, #T_72ee7_row12_col12, #T_72ee7_row13_col13, #T_72ee7_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72ee7_row0_col1, #T_72ee7_row7_col0, #T_72ee7_row9_col0, #T_72ee7_row13_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_72ee7_row0_col2, #T_72ee7_row0_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_72ee7_row0_col4, #T_72ee7_row4_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_72ee7_row0_col5, #T_72ee7_row11_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_72ee7_row0_col6, #T_72ee7_row6_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_72ee7_row0_col7, #T_72ee7_row0_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_72ee7_row0_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_72ee7_row0_col10, #T_72ee7_row8_col4, #T_72ee7_row10_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_72ee7_row0_col11, #T_72ee7_row7_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_72ee7_row0_col12, #T_72ee7_row4_col10 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_72ee7_row0_col13 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_72ee7_row0_col14, #T_72ee7_row2_col5, #T_72ee7_row9_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_72ee7_row1_col0, #T_72ee7_row3_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_72ee7_row1_col2, #T_72ee7_row3_col10, #T_72ee7_row9_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_72ee7_row1_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_72ee7_row1_col4, #T_72ee7_row4_col1, #T_72ee7_row4_col2, #T_72ee7_row5_col0, #T_72ee7_row5_col13, #T_72ee7_row11_col3, #T_72ee7_row11_col14, #T_72ee7_row13_col1, #T_72ee7_row13_col4, #T_72ee7_row13_col5, #T_72ee7_row13_col6, #T_72ee7_row13_col7, #T_72ee7_row13_col9, #T_72ee7_row13_col10, #T_72ee7_row13_col12, #T_72ee7_row14_col8, #T_72ee7_row14_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_72ee7_row1_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_72ee7_row1_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_72ee7_row1_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_72ee7_row1_col8 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_72ee7_row1_col9, #T_72ee7_row5_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_72ee7_row1_col10, #T_72ee7_row7_col14, #T_72ee7_row8_col13, #T_72ee7_row9_col14 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_72ee7_row1_col11, #T_72ee7_row2_col6, #T_72ee7_row3_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_72ee7_row1_col12, #T_72ee7_row3_col12, #T_72ee7_row3_col14, #T_72ee7_row6_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_72ee7_row1_col13, #T_72ee7_row4_col13, #T_72ee7_row8_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_72ee7_row1_col14, #T_72ee7_row4_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_72ee7_row2_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_72ee7_row2_col1, #T_72ee7_row2_col8, #T_72ee7_row7_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_72ee7_row2_col3, #T_72ee7_row11_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_72ee7_row2_col4, #T_72ee7_row12_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_72ee7_row2_col7, #T_72ee7_row9_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_72ee7_row2_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_72ee7_row2_col10, #T_72ee7_row3_col9, #T_72ee7_row10_col14 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_72ee7_row2_col11, #T_72ee7_row5_col10, #T_72ee7_row11_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_72ee7_row2_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_72ee7_row2_col13, #T_72ee7_row6_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_72ee7_row2_col14 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_72ee7_row3_col0, #T_72ee7_row4_col3, #T_72ee7_row8_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_72ee7_row3_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_72ee7_row3_col2, #T_72ee7_row13_col14 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_72ee7_row3_col5, #T_72ee7_row4_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_72ee7_row3_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_72ee7_row3_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_72ee7_row3_col11 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_72ee7_row3_col13, #T_72ee7_row4_col0, #T_72ee7_row9_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_72ee7_row4_col5, #T_72ee7_row7_col11 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_72ee7_row4_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_72ee7_row4_col8, #T_72ee7_row5_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_72ee7_row4_col12 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_72ee7_row4_col14 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_72ee7_row5_col1, #T_72ee7_row12_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_72ee7_row5_col2, #T_72ee7_row14_col0, #T_72ee7_row14_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_72ee7_row5_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_72ee7_row5_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_72ee7_row5_col6, #T_72ee7_row11_col10 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_72ee7_row5_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_72ee7_row5_col11, #T_72ee7_row8_col2, #T_72ee7_row9_col2, #T_72ee7_row10_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_72ee7_row5_col12, #T_72ee7_row7_col10 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_72ee7_row5_col14 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col2, #T_72ee7_row9_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_72ee7_row6_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_72ee7_row6_col10, #T_72ee7_row6_col12, #T_72ee7_row8_col1, #T_72ee7_row8_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_72ee7_row6_col11 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_72ee7_row6_col13 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_72ee7_row6_col14 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_72ee7_row7_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_72ee7_row7_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_72ee7_row7_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_72ee7_row7_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_72ee7_row7_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_72ee7_row7_col9, #T_72ee7_row9_col7 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_72ee7_row7_col12 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_72ee7_row7_col13, #T_72ee7_row12_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_72ee7_row8_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_72ee7_row8_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_72ee7_row8_col9 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_72ee7_row8_col10 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_72ee7_row8_col11 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_72ee7_row8_col12 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_72ee7_row8_col14 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_72ee7_row9_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_72ee7_row9_col8 {
#   background-color: #f5

# %%
corr=x_test.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_97bac_row0_col0, #T_97bac_row1_col1, #T_97bac_row2_col2, #T_97bac_row3_col3, #T_97bac_row4_col4, #T_97bac_row5_col5, #T_97bac_row6_col6, #T_97bac_row7_col7, #T_97bac_row8_col8, #T_97bac_row9_col9, #T_97bac_row10_col10, #T_97bac_row11_col11, #T_97bac_row12_col12, #T_97bac_row13_col13, #T_97bac_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col2, #T_97bac_row8_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col3, #T_97bac_row7_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col4, #T_97bac_row11_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_97bac_row0_col5, #T_97bac_row5_col9, #T_97bac_row10_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_97bac_row0_col6, #T_97bac_row2_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_97bac_row0_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col8, #T_97bac_row0_col10, #T_97bac_row2_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_97bac_row0_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_97bac_row0_col11, #T_97bac_row0_col14, #T_97bac_row2_col5, #T_97bac_row6_col12, #T_97bac_row9_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_97bac_row0_col12 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_97bac_row0_col13 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_97bac_row1_col0, #T_97bac_row3_col4, #T_97bac_row12_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_97bac_row1_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_97bac_row1_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_97bac_row1_col4, #T_97bac_row4_col1, #T_97bac_row4_col2, #T_97bac_row5_col0, #T_97bac_row5_col13, #T_97bac_row11_col3, #T_97bac_row11_col14, #T_97bac_row13_col1, #T_97bac_row13_col4, #T_97bac_row13_col5, #T_97bac_row13_col6, #T_97bac_row13_col7, #T_97bac_row13_col9, #T_97bac_row13_col10, #T_97bac_row13_col12, #T_97bac_row14_col8, #T_97bac_row14_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_97bac_row1_col5, #T_97bac_row3_col14, #T_97bac_row8_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_97bac_row1_col6, #T_97bac_row2_col6, #T_97bac_row3_col6, #T_97bac_row8_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_97bac_row1_col7, #T_97bac_row5_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_97bac_row1_col8, #T_97bac_row7_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_97bac_row1_col9, #T_97bac_row3_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_97bac_row1_col10 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_97bac_row1_col11 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_97bac_row1_col12, #T_97bac_row3_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_97bac_row1_col13, #T_97bac_row4_col0, #T_97bac_row4_col13, #T_97bac_row12_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_97bac_row1_col14, #T_97bac_row2_col13, #T_97bac_row6_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_97bac_row2_col0, #T_97bac_row3_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_97bac_row2_col3, #T_97bac_row11_col12, #T_97bac_row14_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_97bac_row2_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_97bac_row2_col7, #T_97bac_row10_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_97bac_row2_col8, #T_97bac_row9_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_97bac_row2_col9 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_97bac_row2_col11, #T_97bac_row2_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_97bac_row2_col14 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_97bac_row3_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_97bac_row3_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_97bac_row3_col5, #T_97bac_row4_col9, #T_97bac_row5_col10, #T_97bac_row8_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_97bac_row3_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_97bac_row3_col8, #T_97bac_row4_col11, #T_97bac_row6_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_97bac_row3_col9, #T_97bac_row8_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_97bac_row3_col10, #T_97bac_row10_col14 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_97bac_row3_col13 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_97bac_row4_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_97bac_row4_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_97bac_row4_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_97bac_row4_col7, #T_97bac_row9_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_97bac_row4_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_97bac_row4_col10, #T_97bac_row7_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_97bac_row4_col12 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_97bac_row4_col14 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_97bac_row5_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_97bac_row5_col2, #T_97bac_row12_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_97bac_row5_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_97bac_row5_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_97bac_row5_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_97bac_row5_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_97bac_row5_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_97bac_row5_col12 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_97bac_row5_col14 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col3, #T_97bac_row9_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col4, #T_97bac_row7_col13, #T_97bac_row9_col13 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_97bac_row6_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_97bac_row6_col8 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_97bac_row6_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_97bac_row6_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_97bac_row6_col13 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_97bac_row6_col14 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_97bac_row7_col0, #T_97bac_row9_col0, #T_97bac_row12_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_97bac_row7_col1, #T_97bac_row7_col14, #T_97bac_row8_col13 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_97bac_row7_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_97bac_row7_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_97bac_row7_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_97bac_row7_col9, #T_97bac_row9_col7 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_97bac_row7_col10 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_97bac_row7_col11, #T_97bac_row12_col9 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_97bac_row7_col12 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_97bac_row8_col0, #T_97bac_row14_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_97bac_row8_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_97bac_row8_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_97bac_row8_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_97bac_row8_col9 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_97bac_row8_col10 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_97bac_row8_col11, #T_97bac_row12_col10 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_97bac_row8_col14, #T_97bac_row14_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
clf = SVC(kernel='linear',C=0.01,gamma=100,probability=True)
len(x_train)
# Out:
# 83143

# %%
import numpy as np
np.isnan(x_train)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from sklearn.decomposition import PCA  # PCA 추가
import time
# VotingClassifier 생성
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
len(x_train)
# Out:
# 83143

# %%
len(y)
# Out:
# 103929

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA  # PCA 추가
import time
len(x_test)
# Out:
# 20786

# %%
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_clf = accuracy_score(y_test, y_pred)

# %%
  print(f"Accuracy of clf: {accuracy_clf}")
# Out:
# Accuracy of clf: 0.9870585971326855

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming y_test and y_pred_rf are defined
print(y_test.unique())
# Compute confusion matrix
cm1 = confusion_matrix(y_test, y_pred)

# Compute metrics
f1_1 = f1_score(y_test, y_pred, average='macro')
precision_1 = precision_score(y_test, y_pred, average='macro')
recall_1 = recall_score(y_test, y_pred, average='macro')

# Plotting
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.set_title('Confusion Matrix (RF) Case 10', fontsize=14)
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
ax.text(0.5, -0.15, f'F1 Score: {f1_1:.4f} Precision: {precision_1:.4f} Recall: {recall_1:.4f}',
        horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,
        fontsize=12)

# Heatmap
sns.heatmap(cm1, annot=True, fmt="d", cmap="Blues", ax=ax)

# Adjust subplot spacing
plt.tight_layout()
plt.show()
# Out:
# ['Attack' 'Normal']

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[11672     0]
#  [  269  8845]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Attack       0.98      1.00      0.99     11672
#       Normal       1.00      0.97      0.99      9114
#
#     accuracy                           0.99     20786
#    macro avg       0.99      0.99      0.99     20786
# weighted avg       0.99      0.99      0.99     20786

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Colab 시작 페이지</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>&#40;신규&#41; Gemini API를 사용해 보세요</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# Colab에 이미 익숙하다면 이 동영상을 통해 양방향 테이블, 코드 실행 기록 보기, 명령어 팔레트에 관해 알아보세요.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Google Colab의 유용한 기능 3가지를 보여주는 동영상 썸네일' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Colab이란?</h2>
# </div>
#
# Colaboratory&#40;줄여서 'Colab'이라고 함&#41;을 통해 브라우저 내에서 Python 스크립트를 작성하고 실행할 수 있습니다.
# - 구성이 필요하지 않음
# - 무료로 GPU 사용
# - 간편한 공유
#
# <strong>학생</strong>이든, <strong>데이터 과학자</strong>든, <strong>AI 연구원</strong>이든 Colab으로 업무를 더욱 간편하게 처리할 수 있습니다. <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Colab 소개 영상</a>에서 자세한 내용을 확인하거나 아래에서 시작해 보세요.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>시작하기</strong>
# </div>
#
# 지금 읽고 계신 문서는 정적 웹페이지가 아니라 코드를 작성하고 실행할 수 있는 대화형 환경인 <strong>Colab 메모장</strong>입니다.
#
# 예를 들어 다음은 값을 계산하여 변수로 저장하고 결과를 출력하는 간단한 Python 스크립트가 포함된 <strong>코드 셀</strong>입니다.

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# 위 셀의 코드를 실행하려면 셀을 클릭하여 선택한 후 코드 왼쪽의 실행 버튼을 누르거나 단축키 'Command/Ctrl+Enter'를 사용하세요. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.
#
# 특정 셀에서 정의한 변수를 나중에 다른 셀에서 사용할 수 있습니다.

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab 메모장을 사용하면 <strong>실행 코드</strong>와 <strong>서식 있는 텍스트</strong>를 <strong>이미지</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> 등과 함께 하나의 문서로 통합할 수 있습니다. Colab 메모장을 만들면 Google Drive 계정에 저장됩니다. Colab 메모장을 간편하게 공유하여 동료나 친구들이 댓글을 달거나 수정하도록 할 수 있습니다. 자세히 알아보려면 <a href="/notebooks/basic_features_overview.ipynb">Colab 개요</a>를 참조하세요. 새 Colab 메모장을 만들려면 위의 파일 메뉴를 사용하거나 다음 링크로 이동하세요. <a href="http://colab.research.google.com#create=true">새 Colab 메모장 만들기</a>
#
# Colab 메모장은 Colab에서 호스팅하는 Jupyter 메모장입니다. Jupyter 프로젝트에 관해 자세히 알아보려면 <a href="https://www.jupyter.org">jupyter.org</a>를 참조하세요.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## 데이터 과학
# </div>
#
# Colab을 통해 인기 있는 Python 라이브러리를 최대한 활용하여 데이터를 분석하고 시각화할 수 있습니다. 아래 코드 셀에서는 <strong>Numpy</strong>를 사용하여 임의의 데이터를 생성하고 <strong>매트플롯립</strong>으로 이를 시각화합니다. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Google Drive 계정에서 스프레드시트를 비롯한 데이터를 Colab 메모장으로 가져오거나 GitHub 등의 여러 다른 소스에서 데이터를 가져올 수 있습니다. Colab을 데이터 과학에 활용하는 방법과 데이터 가져오기에 관해 자세히 알아보려면 <a href="#working-with-data">데이터 사용하기</a> 아래 링크를 참조하세요.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## 머신러닝
# </div>
#
# Colab을 사용하면 <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">코드 몇 줄</a>만으로 이미지 데이터세트를 가져오고, 이 데이터세트로 이미지 분류기를 학습시키며, 모델을 평가할 수 있습니다. Colab 메모장은 Google 클라우드 서버에서 코드를 실행하므로 사용 중인 컴퓨터의 성능과 관계없이 <a href="#using-accelerated-hardware">GPU 및 TPU</a>를 포함한 Google 하드웨어의 성능을 활용할 수 있습니다. 브라우저만 있으면 사용 가능합니다.

# %% [markdown]
# Colab은 다음과 같은 분야의 머신러닝 커뮤니티에서 널리 쓰이고 있습니다.
# - TensorFlow 시작하기
# - 신경망 개발 및 학습시키기
# - TPU로 실험하기
# - AI 연구 보급하기
# - 튜토리얼 만들기
#
# 머신러닝 적용 사례를 보여 주는 Colab 메모장 샘플을 확인하려면 아래 <a href="#machine-learning-examples">머신러닝 예시</a>를 참조하세요.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## 추가 리소스
#
# ### Colab에서 메모장 사용하기
#
# </div>
#
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
# - [라이브러리 가져오기 및 종속 항목 설치하기](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub에서 노트 저장 및 로드하기](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [대화형 양식](/notebooks/forms.ipynb)
# - [대화형 위젯](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### 데이터로 작업하기
# </div>
#
# - [데이터 로드: 드라이브, 스프레드시트, Google Cloud Storage](/notebooks/io.ipynb)
# - [차트: 데이터 시각화하기](/notebooks/charts.ipynb)
# - [BigQuery 시작하기](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### 머신러닝 단기집중과정
#
# <div>
#
# 다음은 Google 온라인 머신러닝 과정에서 가져온 일부 메모장입니다. <a href="https://developers.google.com/machine-learning/crash-course/">전체 과정 웹사이트</a>에서 자세한 내용을 확인하세요.
# - [Pandas DataFrame 소개](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [합성 데이터를 사용하는 tf.keras 선형 회귀](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### 가속 하드웨어 사용하기
# </div>
#
# - [GPU를 사용한 TensorFlow](/notebooks/gpu.ipynb)
# - [TPU를 사용한 TensorFlow](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### 추천 예시
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>: Nvidia의 NeMo 대화형 AI 툴킷을 사용하여 오디오 파일의 음성을 컴퓨터에서 생성된 음성으로 변환하세요.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">이미지 분류기 재훈련</a>: 사전에 훈련된 이미지 분류기를 기반으로 꽃을 분류하기 위한 Keras 모델을 구축합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">텍스트 분류</a>: IMDB 영화 리뷰를 <em>긍정적인 리뷰</em> 또는 <em>부정적인 리뷰</em>로 분류합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">스타일 트랜스퍼</a>: 딥 러닝을 사용하여 이미지 간에 스타일을 전이시킵니다.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: 머신러닝 모델을 사용하여 SQuAD 데이터 세트의 질문에 답변합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">동영상 보간 유형</a>: 동영상에서 첫 프레임과 마지막 프레임 사이에 발생한 내용을 예측합니다.
