# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/y0uC4N/preprocessing/type3.csv')

sample_fraction = 1
df = df.sample(frac=sample_fraction, random_state=42)

df
# Out:
#           type        time  isCan0  priority  messageID  isService  \
# 74357   Normal   80.359267       1        16       1034          0
# 19739   Normal   42.426692       1         5       1030          0
# 7180    Normal   22.748097       1         5       1030          0
# 162919  Normal  146.060686       1         5       1030          0
# 154241  Attack  140.704216       1         5       1030          0
# ...        ...         ...     ...       ...        ...        ...
# 119879  Attack  113.604328       1         5       1030          0
# 103694  Attack  103.845543       1         5       1030          0
# 131932  Normal  123.029643       1         5       1030          0
# 146867  Normal  136.190676       1         5       1030          0
# 121958  Attack  114.870569       1         5       1030          0
#
#         serviceNODEID  byteSize  data[0]  data[1]  data[2]  data[3]  data[4]  \
# 74357             124         8       74      176       59      200       92
# 19739               1         8      204      135       64       45       48
# 7180                1         8      143      121        1        0        4
# 162919              1         7      127      223        0       64        1
# 154241              1         7      211       52        2      201      252
# ...               ...       ...      ...      ...      ...      ...      ...
# 119879              1         8      216       18      221      207      137
# 103694              1         7      186      188       88      220      192
# 131932              1         7      127      223        0       64        1
# 146867              1         8       56       93      210       22      120
# 121958              1         8      220      234      186       71      205
#
#         data[5]  data[6]  data[7]  7byteNullCnt  8byteNullCnt
# 74357       188       36       63             0             0
# 19739       146        0      149             0             1
# 7180          0       16      130             0             2
# 162919        0      123       -1             2             0
# 154241      214       98       -1             0             0
# ...         ...      ...      ...           ...           ...
# 119879       75       29      132             0             0
# 103694      211      107       -1             0             0
# 131932        0      116       -1             2             0
# 146867       50        0      157             0             1
# 121958      155      124      137             0             0
#
# [197479 rows x 18 columns]

# %%
df.isnull().sum()
df
# Out:
#           type        time  isCan0  priority  messageID  isService  \
# 74357   Normal   80.359267       1        16       1034          0
# 19739   Normal   42.426692       1         5       1030          0
# 7180    Normal   22.748097       1         5       1030          0
# 162919  Normal  146.060686       1         5       1030          0
# 154241  Attack  140.704216       1         5       1030          0
# ...        ...         ...     ...       ...        ...        ...
# 119879  Attack  113.604328       1         5       1030          0
# 103694  Attack  103.845543       1         5       1030          0
# 131932  Normal  123.029643       1         5       1030          0
# 146867  Normal  136.190676       1         5       1030          0
# 121958  Attack  114.870569       1         5       1030          0
#
#         serviceNODEID  byteSize  data[0]  data[1]  data[2]  data[3]  data[4]  \
# 74357             124         8       74      176       59      200       92
# 19739               1         8      204      135       64       45       48
# 7180                1         8      143      121        1        0        4
# 162919              1         7      127      223        0       64        1
# 154241              1         7      211       52        2      201      252
# ...               ...       ...      ...      ...      ...      ...      ...
# 119879              1         8      216       18      221      207      137
# 103694              1         7      186      188       88      220      192
# 131932              1         7      127      223        0       64        1
# 146867              1         8       56       93      210       22      120
# 121958              1         8      220      234      186       71      205
#
#         data[5]  data[6]  data[7]  7byteNullCnt  8byteNullCnt
# 74357       188       36       63             0             0
# 19739       146        0      149             0             1
# 7180          0       16      130             0             2
# 162919        0      123       -1             2             0
# 154241      214       98       -1             0             0
# ...         ...      ...      ...           ...           ...
# 119879       75       29      132             0             0
# 103694      211      107       -1             0             0
# 131932        0      116       -1             2             0
# 146867       50        0      157             0             1
# 121958      155      124      137             0             0
#
# [197479 rows x 18 columns]

# %%
x=df.drop('type',axis=1)
y=df['type']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
x_train=x_train.drop('isCan0',axis=1)
x_train=x_train.drop('isService',axis=1)
x_test=x_test.drop('isCan0',axis=1)
x_test=x_test.drop('isService',axis=1)

corr=x_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_
{
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b0f25_row3_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_b0f25_row3_col2, #T_b0f25_row3_col11, #T_b0f25_row8_col0, #T_b0f25_row13_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b0f25_row3_col4, #T_b0f25_row10_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b0f25_row3_col6, #T_b0f25_row13_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b0f25_row3_col8, #T_b0f25_row13_col14 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b0f25_row3_col12, #T_b0f25_row5_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b0f25_row3_col14, #T_b0f25_row7_col9, #T_b0f25_row9_col7, #T_b0f25_row12_col4 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_b0f25_row4_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b0f25_row4_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b0f25_row4_col3, #T_b0f25_row5_col4, #T_b0f25_row10_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b0f25_row4_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_b0f25_row4_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b0f25_row4_col9 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_b0f25_row4_col10, #T_b0f25_row7_col12 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b0f25_row4_col11 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b0f25_row4_col12 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_b0f25_row4_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b0f25_row4_col14 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_b0f25_row5_col1, #T_b0f25_row11_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b0f25_row5_col3, #T_b0f25_row9_col3, #T_b0f25_row10_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b0f25_row5_col6, #T_b0f25_row11_col0, #T_b0f25_row13_col0, #T_b0f25_row14_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b0f25_row5_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b0f25_row5_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b0f25_row5_col14, #T_b0f25_row8_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b0f25_row6_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b0f25_row6_col1, #T_b0f25_row8_col5, #T_b0f25_row14_col10 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b0f25_row6_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b0f25_row6_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b0f25_row6_col4, #T_b0f25_row11_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b0f25_row6_col9, #T_b0f25_row12_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b0f25_row6_col10, #T_b0f25_row9_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b0f25_row6_col11, #T_b0f25_row13_col11 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b0f25_row6_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b0f25_row6_col13, #T_b0f25_row9_col12 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b0f25_row7_col0, #T_b0f25_row9_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b0f25_row7_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b0f25_row7_col2, #T_b0f25_row8_col2, #T_b0f25_row9_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b0f25_row7_col3, #T_b0f25_row13_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b0f25_row7_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b0f25_row7_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b0f25_row7_col10 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b0f25_row7_col13, #T_b0f25_row12_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b0f25_row8_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b0f25_row8_col3, #T_b0f25_row10_col5, #T_b0f25_row11_col12, #T_b0f25_row14_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b0f25_row8_col6, #T_b0f25_row12_col8, #T_b0f25

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
clf = SVC(kernel='linear',C=0.01,gamma=100,probability=True)
len(x_train)
# Out:
# 157983

# %%
import numpy as np
np.isnan(x_train)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from sklearn.decomposition import PCA  # PCA 추가
import time
# VotingClassifier 생성
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
len(x_train)
# Out:
# 157983

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA  # PCA 추가
import time
len(x_test)
# Out:
# 39496

# %%
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming y_test and y_pred_rf are defined
print(y_test.unique())
# Compute confusion matrix
cm1 = confusion_matrix(y_test, y_pred)

# Compute metrics
f1_1 = f1_score(y_test, y_pred, average='macro')
precision_1 = precision_score(y_test, y_pred, average='macro')
recall_1 = recall_score(y_test, y_pred, average='macro')

# Plotting
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.set_title('Confusion Matrix (RF) Case 10', fontsize=14)
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
ax.text(0.5, -0.15, f'F1 Score: {f1_1:.4f} Precision: {precision_1:.4f} Recall: {recall_1:.4f}',
        horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,
        fontsize=12)

# Heatmap
sns.heatmap(cm1, annot=True, fmt="d", cmap="Blues", ax=ax)

# Adjust subplot spacing
plt.tight_layout()
plt.show()
# Out:
# ['Attack' 'Normal']

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[18950   235]
#  [  547 19764]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Attack       0.97      0.99      0.98     19185
#       Normal       0.99      0.97      0.98     20311
#
#     accuracy                           0.98     39496
#    macro avg       0.98      0.98      0.98     39496
# weighted avg       0.98      0.98      0.98     39496
